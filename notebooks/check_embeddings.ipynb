# %%
import pickle


path = '/home/turbotowerlnx/Documents/Master/ALC/ALC-Lab-Final/data/EXIST 2026 Videos Dataset/test/video_embeddings_gemma4_31b-test.pkl'


with open(path, 'rb') as f:
    data = pickle.load(f)

print(data)

# %%
import pickle


path = '../data/EXIST 2026 Videos Dataset/training/video_embeddings_ville.pkl'


with open(path, 'rb') as f:
    data = pickle.load(f)

print(len(data))
print(data)

# %%
import pickle


path = '../data/EXIST 2026 Videos Dataset/test/video_embeddings_ville.pkl'


with open(path, 'rb') as f:
    data = pickle.load(f)

print(len(data))
print(data)
