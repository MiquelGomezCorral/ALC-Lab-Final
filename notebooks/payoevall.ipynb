# %%
def vote_to_label(votes):
    """
    Convierte votos binarios a etiqueta {'YES','NO'} con desempate determinista.
    Regla igual a argmax sobre [count_NO, count_YES]: en empate gana NO.
    """
    if not votes:
        return None

    no_count = sum(1 for v in votes if int(v) == 0)
    yes_count = sum(1 for v in votes if int(v) == 1)
    return "YES" if yes_count > no_count else "NO"

# %%
from maikol_utils.file_utils import load_json

pred_path = '../data/processed/predictions/xlm-roberta-base_test_loaded_model.json'
ref_path = '../data/processed/test_payo.json'

test_data = load_json('../data/processed/test.json')
preds = load_json(pred_path)

# Referencia determinista alineada con la lógica usada en evaluate (argmax en empate -> NO).
test = [
    {
        'id': str(s['id']),
        'test_case': 'EXIST2026',
        'value': vote_to_label(s['label'])
    }
    for s in test_data
]

# Chequeos de consistencia antes de evaluar
pred_ids = [str(x['id']) for x in preds]
ref_ids = [str(x['id']) for x in test]
print(f'pred_path={pred_path}')
print(f'n_preds={len(preds)} | n_ref={len(test)}')
print(f'ids_orden_igual={pred_ids == ref_ids}')
print(f'ids_set_igual={set(pred_ids) == set(ref_ids)}')
# Out:
# Loading output from ../data/processed/test.json...
# Loading output from ../data/processed/predictions/xlm-roberta-base_test_loaded_model.json...
# pred_path=../data/processed/predictions/xlm-roberta-base_test_loaded_model.json
# n_preds=502 | n_ref=502
# ids_orden_igual=True
# ids_set_igual=True

# %%
from maikol_utils.file_utils import save_json
save_json('../data/processed/test_payo.json', test)
# Out:
# Saving output at ../data/processed/test_payo.json...
# [{'id': '120005', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120008', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120012', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120017', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120018', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120021', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120023', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120027', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120029', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120031', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120035', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120036', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120040', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120053', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120056', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120066', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120068', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120082', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120090', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120094', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120107', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120109', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120121', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120135', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120138', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120144', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120150', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120154', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120156', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120159', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120161', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120163', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120170', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120193', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120205', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120207', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120208', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120214', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120215', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120219', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120221', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120225', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120228', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120241', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120243', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120244', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120247', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120249', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120251', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120254', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120256', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120258', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120262', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120263', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120272', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120278', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120281', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120283', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120287', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120288', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120291', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120296', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120306', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120308', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120309', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120310', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120321', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120323', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120327', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120334', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120337', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120338', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120346', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120348', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120352', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120365', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120369', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120370', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120372', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120379', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120382', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120386', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120391', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120406', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120408', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120415', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120419', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120424', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120429', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120440', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120451', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120461', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120471', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120479', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120485', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120487', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120492', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120502', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120519', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120527', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120530', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120546', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120548', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120550', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120558', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120561', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120566', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120577', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120579', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120580', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120583', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120589', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120592', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120593', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120598', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120602', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120603', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120607', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120615', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120620', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120633', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120643', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120647', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120648', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120650', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120651', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120652', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120655', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120656', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120663', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120665', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120672', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120674', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120679', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120680', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120691', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120693', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120696', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120699', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120703', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120706', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120710', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120715', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120722', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120725', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120730', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120738', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120743', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120750', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120752', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120758', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120766', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120777', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120780', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120784', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120805', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120807', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120808', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120809', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120817', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120822', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120838', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120843', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120848', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120855', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120857', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120866', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120867', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120871', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120891', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120893', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120894', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120896', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120897', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120899', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120900', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120904', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120907', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120922', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120923', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120925', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120926', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120929', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120933', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120934', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120945', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120951', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120968', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120969', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120972', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120977', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120981', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '120985', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '120990', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121004', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121008', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121011', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121013', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121015', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121016', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121017', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121021', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121022', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121039', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121040', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121046', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121053', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121065', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121066', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121070', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121072', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121075', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121076', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121084', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121088', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121090', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121091', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121107', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121108', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121116', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121133', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121136', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121137', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121139', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121144', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121147', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121149', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121159', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121165', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121166', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121168', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121171', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121172', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121173', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121179', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121188', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121192', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121195', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121212', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121222', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121226', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121231', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121232', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121234', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121236', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121239', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121242', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121251', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121253', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121262', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121265', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121270', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121273', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121275', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121283', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121285', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121292', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121294', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121297', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121302', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121303', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121312', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121314', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121317', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121319', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121328', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121330', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121333', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121339', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121340', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121345', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121352', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121353', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121358', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121360', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121363', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121364', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121373', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121377', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121388', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121391', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220003', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220011', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220014', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220015', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220025', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220032', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220046', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220054', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220056', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220057', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220061', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220064', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220067', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220069', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220071', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220072', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220073', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220082', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220088', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220089', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220094', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220098', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220101', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220103', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220105', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220108', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220114', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220120', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220121', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220123', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220136', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220140', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220142', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220144', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220159', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220162', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220168', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220170', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220176', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220178', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220183', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220184', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220188', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220189', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220191', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220198', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220201', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220206', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220211', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220214', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220224', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220237', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220240', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220247', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220253', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220256', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220257', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220258', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220260', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220279', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220280', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220282', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220287', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220293', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220298', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220299', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220315', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220318', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220335', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220341', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220350', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220364', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220366', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220370', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220381', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220382', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220386', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220393', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220408', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220409', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220414', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220415', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220417', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220421', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220422', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220433', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220438', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220439', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220440', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220449', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220456', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220470', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220471', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220475', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220479', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220480', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220482', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220491', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220509', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220518', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220522', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220525', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220530', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220531', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220542', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220543', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220559', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220561', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220564', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220567', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220568', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220570', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220576', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220580', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220588', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220590', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220591', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220595', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220599', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220603', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220607', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220609', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220616', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220619', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220625', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220627', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220628', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220634', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220636', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220640', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220653', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220656', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220661', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220665', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220678', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220683', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220686', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220691', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220693', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220701', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220703', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220707', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220717', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220734', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220736', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220740', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220749', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220753', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220757', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220760', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220763', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220774', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220782', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220783', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220787', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220788', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220791', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220795', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220810', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220811', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220816', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220818', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220820', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220821', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220825', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220826', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220828', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220839', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220844', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220849', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220856', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220870', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220875', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220876', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220880', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220889', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220894', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220895', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220900', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220906', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220917', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220924', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220925', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220933', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220944', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220947', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220950', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220953', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220954', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220957', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220961', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220965', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220967', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220969', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220977', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220983', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '220989', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '220991', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '221000', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121400', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121412', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121417', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121424', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121432', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121435', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121436', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121442', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121445', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121446', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121451', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121460', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121461', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121472', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121474', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121477', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121509', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121510', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121512', 'test_case': 'EXIST2026', 'value': 'NO'},
#  {'id': '121515', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121520', 'test_case': 'EXIST2026', 'value': 'YES'},
#  {'id': '121523', 'test_case': 'EXIST2026', 'value': 'NO'}]

# %%
from pyevall.evaluation import PyEvALLEvaluation
from pyevall.metrics.metricfactory import MetricFactory
from itertools import combinations

test = PyEvALLEvaluation()
ref_path = '../data/processed/test_payo.json'

pred_path = [
    '../data/processed/predictions/send/turboabuelas_trainedonboth.json',
'../data/processed/predictions/send/turboabuelas_trainedonenglish.json', 
 '../data/processed/predictions/send/turboabuelas_trainedonspanish.json' 
]

for f in pred_path:
    print(f'=========================================================')
    print(f'Evaluando predicciones de: {f}')
    print(f'=========================================================')

    files = [
        f,
        ref_path,
    ]

    metrics = [
        MetricFactory.Accuracy.value,
        MetricFactory.FMeasure.value,
    ]

    params = dict()

    for preds_file, labels_file in combinations(files, 2):
        print(f"\nEvaluando:\nPreds: {preds_file}\nLabels: {labels_file}\n")
        report = test.evaluate(preds_file, labels_file, metrics, **params)
        report.print_report()
# Out:
# =========================================================
# Evaluando predicciones de: ../data/processed/predictions/send/turboabuelas_trainedonboth.json
# =========================================================
#
# Evaluando:
# Preds: ../data/processed/predictions/send/turboabuelas_trainedonboth.json
# Labels: ../data/processed/test_payo.json
#
# 2026-04-01 19:03:02,162 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['Accuracy', 'FMeasure']
# 2026-04-01 19:03:02,180 - pyevall.metrics.metrics - INFO -             evaluate() - Executing accuracy evaluation method
# 2026-04-01 19:03:02,215 - pyevall.metrics.metrics - INFO -             evaluate() - Executing fmeasure evaluation method
# {
#   "metrics": {
#     "Accuracy": {
#       "name": "Accuracy",
#       "acronym": "Acc",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "average": 0.7390438247011952
#         }],
#         "average_per_test_case": 0.7390438247011952
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "classes": {
#             "YES": 0.7495219885277247,
#             "NO": 0.7276507276507276
#           },
#           "average": 0.7385863580892261
#         }],
#         "average_per_test_case": 0.7385863580892261
#       }
#     }
#   },
#   "files": {
#     "turboabuelas_trainedonboth.json": {
#       "name": "turboabuelas_trainedonboth.json",
#       "status": "OK",
#       "gold": false,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     },
#     "test_payo.json": {
#       "name": "test_payo.json",
#       "status": "OK",
#       "gold": true,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     }
#   }
# }
# =========================================================
# Evaluando predicciones de: ../data/processed/predictions/send/turboabuelas_trainedonenglish.json
# =========================================================
#
# Evaluando:
# Preds: ../data/processed/predictions/send/turboabuelas_trainedonenglish.json
# Labels: ../data/processed/test_payo.json
#
# 2026-04-01 19:03:02,217 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['Accuracy', 'FMeasure']
# 2026-04-01 19:03:02,234 - pyevall.metrics.metrics - INFO -             evaluate() - Executing accuracy evaluation method
# 2026-04-01 19:03:02,271 - pyevall.metrics.metrics - INFO -             evaluate() - Executing fmeasure evaluation method
# {
#   "metrics": {
#     "Accuracy": {
#       "name": "Accuracy",
#       "acronym": "Acc",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "average": 0.7370517928286853
#         }],
#         "average_per_test_case": 0.7370517928286853
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "classes": {
#             "YES": 0.736,
#             "NO": 0.738095238095238
#           },
#           "average": 0.737047619047619
#         }],
#         "average_per_test_case": 0.737047619047619
#       }
#     }
#   },
#   "files": {
#     "turboabuelas_trainedonenglish.json": {
#       "name": "turboabuelas_trainedonenglish.json",
#       "status": "OK",
#       "gold": false,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     },
#     "test_payo.json": {
#       "name": "test_payo.json",
#       "status": "OK",
#       "gold": true,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     }
#   }
# }
# =========================================================
# Evaluando predicciones de: ../data/processed/predictions/send/turboabuelas_trainedonspanish.json
# =========================================================
#
# Evaluando:
# Preds: ../data/processed/predictions/send/turboabuelas_trainedonspanish.json
# Labels: ../data/processed/test_payo.json
#
# 2026-04-01 19:03:02,273 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['Accuracy', 'FMeasure']
# 2026-04-01 19:03:02,290 - pyevall.metrics.metrics - INFO -             evaluate() - Executing accuracy evaluation method
# 2026-04-01 19:03:02,326 - pyevall.metrics.metrics - INFO -             evaluate() - Executing fmeasure evaluation method
# {
#   "metrics": {
#     "Accuracy": {
#       "name": "Accuracy",
#       "acronym": "Acc",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "average": 0.7350597609561753
#         }],
#         "average_per_test_case": 0.7350597609561753
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2026",
#           "classes": {
#             "YES": 0.7323943661971831,
#             "NO": 0.7376725838264301
#           },
#           "average": 0.7350334750118066
#         }],
#         "average_per_test_case": 0.7350334750118066
#       }
#     }
#   },
#   "files": {
#     "turboabuelas_trainedonspanish.json": {
#       "name": "turboabuelas_trainedonspanish.json",
#       "status": "OK",
#       "gold": false,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     },
#     "test_payo.json": {
#       "name": "test_payo.json",
#       "status": "OK",
#       "gold": true,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {}
#     }
#   }
# }

# %%
from pyevall.evaluation import PyEvALLEvaluation
from pyevall.utils.utils import PyEvALLUtils
from pyevall.metrics.metricfactory import MetricFactory
test = PyEvALLEvaluation()
labels = '../output/TurboAbuelas_RobertMostro.json'
preds = '../output/TurboAbuelas_Qwen.json'



metrics = [
 MetricFactory.Accuracy.value,
 MetricFactory.FMeasure.value,
]
params= dict()
report = test.evaluate(preds, labels, metrics, **params)
report.print_report()
# report.report, if you want to access the dictionary :)
# Out:
# 2026-04-01 16:52:03,216 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['Accuracy', 'FMeasure']
# {
#   "metrics": {},
#   "files": {
#     "TurboAbuelas_Qwen.json": {
#       "name": "TurboAbuelas_Qwen.json",
#       "status": "FAIL",
#       "gold": false,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {
#         "FORMAT_FILE_NOT_EXIST_ERROR": {
#           "description": "Use parameter: report=\"embedded\"!",
#           "exception": null,
#           "status": "STOP"
#         }
#       }
#     },
#     "TurboAbuelas_RobertMostro.json": {
#       "name": "TurboAbuelas_RobertMostro.json",
#       "status": "FAIL",
#       "gold": true,
#       "description": "Use parameter: report=\"embedded\"!",
#       "errors": {
#         "FORMAT_FILE_NOT_EXIST_ERROR": {
#           "description": "Use parameter: report=\"embedded\"!",
#           "exception": null,
#           "status": "STOP"
#         }
#       }
#     }
#   }
# }
